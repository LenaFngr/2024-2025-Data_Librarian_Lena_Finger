# %% [markdown]
# Aufgabe 3 - Seattle Library Datenanalyse

# %%
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Daten über API beziehen und als CSV-Datei speichern

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7214f551d370>)

# %% [markdown]
# Daten in einen Dataframe laden und analysieren

# %%
checkouts_df = pd.read_csv(checkout_file)
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997    Digital      Freegal         SONG          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
# 9999   Physical      Horizon    SOUNDDISC          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
checkouts_df.shape
# Out:
# (10000, 12)

# %%
checkouts_df["checkoutmonth"].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  8,  9, 10, 11, 12])

# %%
checkouts_df["checkouts"].max()
# Out:
# 540

# %%
checkouts_df["checkouts"].min()
# Out:
# 1

# %%
checkouts_df["checkouts"].mean()
# Out:
# 3.3392

# %%
checkouts_df["materialtype"].unique()
# Out:
# array(['EBOOK', 'TELEVISION', 'SOUNDDISC', 'BOOK', 'AUDIOBOOK', 'COMIC',
#        'MOVIE', 'SONG', 'MUSIC', 'MAGAZINE', 'VIDEODISC', 'SOUNDREC',
#        'SOUNDDISC, VIDEODISC', 'CR', 'LARGEPRINT', 'ER, SOUNDDISC',
#        'ATLAS', 'ER', 'MAP', 'VIDEOCASS, VIDEODISC', 'REGPRINT', 'VIDEO',
#        'SOUNDCASS', 'ER, VIDEODISC'], dtype=object)

# %%
checkouts_df[checkouts_df["materialtype"] == "EBOOK"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# 5       Digital    OverDrive        EBOOK          2018              1
# 6       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9988    Digital    OverDrive        EBOOK          2018              1
# 9989    Digital    OverDrive        EBOOK          2018              1
# 9992    Digital    OverDrive        EBOOK          2018              1
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
checkouts_ebook_df = checkouts_df[checkouts_df["materialtype"] == "EBOOK"]

# %%
checkouts_ebook_df.shape
# Out:
# (2084, 12)

# %%
checkouts_ebook_df.to_csv("checkout_ebooks_only.csv")

# %%
checkouts_ebook_df.to_excel("checkout_ebooks_only.xlsx")

# %%
checkouts_df["materialtype"].value_counts()
# Out:
# materialtype
# BOOK                    4268
# EBOOK                   2084
# AUDIOBOOK                857
# SOUNDDISC                839
# VIDEODISC                806
# SONG                     707
# MUSIC                    139
# MOVIE                     94
# TELEVISION                85
# COMIC                     62
# SOUNDDISC, VIDEODISC      10
# MAGAZINE                  10
# SOUNDREC                   8
# REGPRINT                   7
# VIDEO                      5
# CR                         4
# ER, SOUNDDISC              3
# ER                         3
# MAP                        3
# ATLAS                      2
# LARGEPRINT                 1
# VIDEOCASS, VIDEODISC       1
# SOUNDCASS                  1
# ER, VIDEODISC              1
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
checkouts_df["materialtype"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='materialtype'>

# %%
plt.show()

# %%
plt.close()

# %%
checkouts_df["materialtype"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='materialtype'>

# %%
plt.show()

# %%
plt.close()

# %%
checkouts_df["checkouts"].hist()
# Out:
# <Axes: >

# %%
plt.show()

# %%
plt.close()

# %%
checkouts_df["materialtype"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='materialtype'>

# %%
checkouts_df[checkouts_df["checkouts"] < 50]["checkouts"].hist(bins = 20)
# Out:
# <Axes: >

# %%
plt.show()

# %%
plt.close()

# %%
checkouts_df["checkoutmonth"].hist()
# Out:
# <Axes: >

# %%
plt.show()

# %%
checkouts_df["checkoutmonth"].value_counts()
# Out:
# checkoutmonth
# 1     9930
# 12      27
# 3       19
# 2       12
# 8        3
# 4        2
# 5        2
# 9        2
# 11       2
# 10       1
# Name: count, dtype: int64

# %%
checkouts_df["subjects"].value_counts()
# Out:
# subjects
# Fiction, Mystery                                                                                                                                                                                                              182
# Fiction, Literature                                                                                                                                                                                                           178
# Fiction, Romance                                                                                                                                                                                                               99
# Juvenile Fiction, Juvenile Literature                                                                                                                                                                                          72
# ...

# %%
subjects = checkouts_df["subjects"].value_counts().rename_axis('subjects').reset_index(name = 'counts')

# %%
checkouts_df["materialtype"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='materialtype'>

# %%
print(subjects)
# Out:
#                                                subjects  counts
# 0                                      Fiction, Mystery     182
# 1                                   Fiction, Literature     178
# 2                                      Fiction, Romance      99
# 3                 Juvenile Fiction, Juvenile Literature      72
# 4                  Fiction, Historical Fiction, Romance      70
# ...                                                 ...     ...
# 6374                  Drawing Technique, Figure drawing       1
# 6375  Science Study and teaching Preschool Activity ...       1
# 6376  Mahabharata Criticism interpretation etc, Illu...       1
# 6377  Orchestral music, Operas Excerpts, Concertos E...       1
# 6378  Space race United States History 20th century,...       1
#
# [6379 rows x 2 columns]

# %%
subjects[subjects["counts"] > 5]["counts"].hist(bins = 20)
# Out:
# <Axes: >

# %%
plt.show()

# %%
checkouts_df["publicationyear"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='publicationyear'>

# %%
plt.show()

# %%
checkouts_df[checkouts_df["publicationyear"] < 2010]["publicationyear"].hist(bins = 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 checkouts_df[checkouts_df["publicationyear"] < 2018]["publicationyear"].hist(bins = 20)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
# ...

# %%
print(checkouts_df["publicationyear"].unique())
# Out:
# ['2017' nan '[2015]' '2009' '2015' '2012' '2000.' '2013' '2008' '2018'
#  '2014' '2016' '[1985]' '[2004]' '2017.' '2010' '2012.' '[2011]' '[1990]'
#  '2015.' '2016.' 'p2013.' '2006' '[2013]' '[1998]' '[2018]' '1944.'
#  '[2010]' '2011.' '2003.' '1992.' '2006.' '[2016]' '2011' '1997.' '1999.'
#  '2005' '2007' '2013.' 'p2014.' '1988.' '1994.' '[1986]' '2010.' '2002.'
#  '[2017]' '[2001?]' '[2014]' '[1985], ℗1977.' '[2000, c2001]' '[2007]'
#  '2009.' '[1987]' '2007.' '2014.' '1985, ©1984.' '[2008]' '1989.' '[2000]'
#  '1983.' '[2009]' '[2012]' '[1994]' '2008.' '[2010], ©1996.' '[2006]'
#  '[2017].' '[2000?]' '[2001]' '2016, [c2015]' '[1990?]' '1972.' 'c2015.'
#  '[1999]' 'c2013.' '[2005]' '2005.' 'c2017.' '1985.' '[1956]' '[2003]'
#  '[2002]' '[between 1970-1979?]' '[2013].' '1998.' '[2009], 2002.'
#  '[1997]' '1995.' '2001.' 'c2007, 2008.' '[2016?]' '2004.' '[1979]'
#  'c2014.' '[2016].' 'c2016.' '[1995]' '[1964]' '[1988]' '1996.' '[1991]'
# ...

# %%
print(checkouts_df.dtypes)
# Out:
# usageclass          object
# checkouttype        object
# materialtype        object
# checkoutyear         int64
# checkoutmonth        int64
# checkouts            int64
# title               object
# isbn               float64
# creator             object
# subjects            object
# publisher           object
# publicationyear     object
# dtype: object

# %%
checkouts_df["publicationyear2"] = pd.to_numeric(checkouts_df["publicationyear"], errors = 'coerce')

# %%
print(checkouts_df.dtypes)
# Out:
# usageclass           object
# checkouttype         object
# materialtype         object
# checkoutyear          int64
# checkoutmonth         int64
# checkouts             int64
# title                object
# isbn                float64
# creator              object
# subjects             object
# publisher            object
# publicationyear      object
# publicationyear2    float64
# dtype: object

# %%
print(checkouts_df["publicationyear2"].unique())
# Out:
# [2017.   nan 2009. 2015. 2012. 2000. 2013. 2008. 2018. 2014. 2016. 2010.
#  2006. 1944. 2011. 2003. 1992. 1997. 1999. 2005. 2007. 1988. 1994. 2002.
#  1989. 1983. 1972. 1985. 1998. 1995. 2001. 2004. 1996. 1993. 1928. 1990.
#  1991. 1970. 1976. 1937. 1969. 1966. 1961. 1964. 1960. 1954. 1986. 1982.
#  1968. 1951. 1939. 1911. 1974. 1940. 1935. 1921. 1973. 1888. 1984. 1965.
#  1926. 1956. 1963. 1910. 1958.]

# %%
checkouts_df[checkouts_df["publicationyear2"] > 1980]["publicationyear2"].hist(bins = 50)
# Out:
# <Axes: >

# %%
plt.show()
