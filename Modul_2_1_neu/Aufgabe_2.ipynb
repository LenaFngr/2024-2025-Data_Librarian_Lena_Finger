# %% [markdown]
# ## Datenaufbereitung

# %%
import json
import pandas as pd

# %%
# Daten aus Aufgabe_1 laden
data = json.load(open("Daten_Aufgabe_1.json"))

# %%
type(data) # Liste muss in DataFrame umgewandelt werden
# Out:
# list

# %%
df = pd.DataFrame(data)
df
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/4fc050ac134e9cb0...
# 1        Bookmark  https://www.bibsonomy.org/url/1239428ed6d8a97d...
# 2        Bookmark  https://www.bibsonomy.org/url/83a50f1e9feb2c64...
# 3        Bookmark  https://www.bibsonomy.org/url/133fef01d7a4636e...
# 4        Bookmark  https://www.bibsonomy.org/url/b6fe240cad5d58ab...
# ...           ...                                                ...
# 5434  Publication  https://www.bibsonomy.org/bibtex/24ecb4fb3f9ba...
# 5435  Publication  https://www.bibsonomy.org/bibtex/22571b87c2696...
# 5436  Publication  https://www.bibsonomy.org/bibtex/24ecb4fb3f9ba...
# 5437  Publication  https://www.bibsonomy.org/bibtex/237366cf55399...
# 5438  Publication  https://www.bibsonomy.org/bibtex/256523ed7914c...
#
#                                                    tags  \
# 0     [unternehmen, betrvg119, betriebsrat, mobbing,...
# 1     [cafe, alternativ, unternehmen, basel, kaffee,...
# 2                  [unternehmen, socialmedia, importmw]
# 3                  [Unternehmenskommunikation, Twitter]
# 4                               [Facebook, Unternehmen]
# ...                                                 ...
# 5434  [tagging, web-2.0, social-software, foundation...
# 5435  [2009, socialSoftware, web2.0, _todo, enterpri...
# 5436  [Social_Software, web_20, KWMaster, Kompetenzm...
# 5437  [stabile_Zustände, Komplexität, dagroup, BWL, ...
# 5438  [stabile_Zustände, Komplexität, dagroup, BWL, ...
#
#                              intraHash  \
# 0     4fc050ac134e9cb060539542888f5dea
# 1     1239428ed6d8a97d43392c014f3edd6f
# 2     83a50f1e9feb2c64ac529fa8d27729cc
# 3     133fef01d7a4636ee9557e4b92eb2000
# 4     b6fe240cad5d58abff4b4f838d7648cd
# ...                                ...
# 5434  4ecb4fb3f9baa4af1d35d9a74b213f12
# 5435  2571b87c2696a4ad0b7dd8039ce1d55c
# 5436  4ecb4fb3f9baa4af1d35d9a74b213f12
# 5437  37366cf5539948e8253238748de83c82
# 5438  56523ed7914cee09798bace6f354b76f
#
#                                                   label         user  \
# 0     Staatliche Unternehmen: Betriebsräte im Schlus...    meneteqel
# 1                               unternehmen mitte basel   tobidiplom
# 2     Unternehmen fehlen die Strukturen fr Social Me...  textundblog
# 3     Twitternde Unternehmen - Kategorie - Twittwoch...       zwobot
# 4              Unternehmen: Was mit Facebook anstellen?     kooptech
# ...                                                 ...          ...
# 5434  Web 2.0 in der Unternehmenspraxis: Grundlagen,...        beate
# 5435  Web 2.0 in der Unternehmenspraxis: Grundlagen,...        trude
# 5436  Web 2.0 in der Unternehmenspraxis: Grundlagen,...    marion_87
# 5437                        Komplexitätsmanagement (II)    chrishi07
# 5438                         Komplexitätsmanagement (I)    chrishi07
#
#                                             description                 date  \
# 0     Der Vorwurf der Gewerkschaften ist pikant. Unt...  2012-01-18 16:59:42
# 1                                                        2008-07-31 15:18:43
# 2     Soziale Medien sind in vielen Unternehmen ein ...  2013-06-28 16:41:36
# 3     Twitternde Unternehmen (28): @internet_world, ...  2009-09-21 12:39:28
# 4                                        ein paar Ideen  2007-12-03 09:52:01
# ...                                                 ...                  ...
# 5434  Social Software Anwendungen wie Wikis, Weblogs...  2011-01-28 16:28:43
# 5435  Social Software Anwendungen wie Wikis, Weblogs...  2010-11-02 17:31:32
# 5436  Social Software Anwendungen wie Wikis, Weblogs...  2009-11-10 13:03:55
# 5437                                                     2007-09-24 12:37:24
# 5438                                                     2007-09-24 12:37:24
#
#                changeDate  count  ... comment   pii medline-pst archiveprefix  \
# 0     2012-01-19 20:02:26      1  ...    None  None        None          None
# 1     2008-07-31 15:18:43      1  ...    None  None        None          None
# 2     2013-06-28 16:41:36      1  ...    None  None        None          None
# 3     2009-09-21 12:39:28      1  ...    None  None        None          None
# 4     2008-02-26 14:50:23      1  ...    None  None        None          None
# ...                   ...    ...  ...     ...   ...         ...           ...
# 5434  2011-01-28 16:28:43      6  ...    None  None        None          None
# 5435  2010-11-02 17:31:32      6  ...    None  None        None          None
# 5436  2009-11-10 13:03:55      6  ...    None  None        None          None
# 5437  2007-09-24 12:37:26      1  ...    None  None        None          None
# 5438  2007-09-24 12:37:26      1  ...    None  None        None          None
#
#      slaccitation jlprojects optmonth added modified keywords
# 0            None       None     None  None     None     None
# 1            None       None     None  None     None     None
# 2            None       None     None  None     None     None
# 3            None       None     None  None     None     None
# 4            None       None     None  None     None     None
# ...           ...        ...      ...   ...      ...      ...
# 5434         None       None     None  None     None     None
# 5435         None       None     None  None     None     None
# 5436         None       None     None  None     None     None
# 5437         None       None     None  None     None     None
# 5438         None       None     None  None     None     None
#
# [5439 rows x 135 columns]

# %% [markdown]
# ### Daten filtern: Einträge des Typs "Publication"

# %%
df_pubs = df.loc[df["type"]== "Publication"]

# %% [markdown]
# ### Daten (Spalten) auswählen und umbenennen

# %%
#

# %% [markdown]
# ### Daten säubern: Einträge zu Titel, Autor und Jahr überprüfen

# %%
#

# %% [markdown]
# ### Duplikate entfernen

# %%
#
